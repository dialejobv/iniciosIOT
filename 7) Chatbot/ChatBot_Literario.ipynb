# %%
import requests

API_KEY = 'sk-53751d5c6f344a5dbc0571de9f51313e'
API_URL = 'https://api.deepseek.com/v1/chat/completions'

def generar_prompt_interactivo():
    """Recolecta parámetros para la historia y construye el prompt"""
    print("\n=== Configura tu historia ===")
    genero = input("Género (ej. fantasía, sci-fi, misterio): ")
    protagonista = input("Protagonista (ej. princesa guerrera, robot poeta): ")
    escenario = input("Escenario (ej. ciudad flotante, bosque de cristal): ")
    tono = input("Tono (ej. épico, oscuro, humorístico): ")
    elementos = input("Elementos especiales (ej. magia, tecnología alienígena): ")

    return f"""Escribe un cuento creativo con estos elementos:
- Género: {genero}
- Protagonista: {protagonista}
- Escenario: {escenario}
- Tono: {tono}
- Incluir: {elementos}
- Estructura: introducción, conflicto, desenlace
- Longitud: 500 palabras aproximadamente
- Estilo narrativo: descriptivo y envolvente
Incluye título creativo y marca los diálogos con guiones."""

def generar_cuento(prompt, temperatura=0.85):
    """Genera la historia con parámetros creativos"""
    headers = {
        'Authorization': f'Bearer {API_KEY}',
        'Content-Type': 'application/json'
    }

    data = {
        'model': 'deepseek-chat',
        'temperature': temperatura,
        'messages': [{
            'role': 'user',
            'content': prompt
        }]
    }

    try:
        response = requests.post(API_URL, headers=headers, json=data)
        response.raise_for_status()
        return response.json()['choices'][0]['message']['content']

    except requests.exceptions.HTTPError as err:
        return f"Error: {err.response.text}"
    except Exception as e:
        return f"Error: {e}"

def menu_modificaciones():
    """Ofrece opciones para modificar la historia generada"""
    print("\n¿Qué deseas hacer ahora?")
    print("1. Agregar un giro dramático")
    print("2. Cambiar el final")
    print("3. Ampliar una escena")
    print("4. Generar nueva historia")
    print("5. Salir")
    return input("Elección: ")

def aplicar_modificacion(historia_original, opcion):
    """Crea nuevos prompts basados en modificaciones"""
    modificaciones = {
        '1': "Agrega un giro dramático inesperado a esta historia:",
        '2': "Reescribe el final de esta historia con un cambio radical:",
        '3': "Amplía la escena más importante con detalles descriptivos:"
    }
    return f"{modificaciones[opcion]}\n\n{historia_original}"

def main():
    print("""¡Bienvenido al Generador de Cuentos Creativos!
(escribe 'salir' en cualquier momento para terminar)""")

    while True:
        # Generar historia base
        prompt = generar_prompt_interactivo()
        historia = generar_cuento(prompt)
        print("\n=== TU CUENTO ===")
        print(historia)

        # Ciclo de modificaciones
        while True:
            opcion = menu_modificaciones()

            if opcion == '4':
                break  # Volver a generar nueva historia
            if opcion == '5':
                print("¡Hasta la próxima aventura!")
                return

            nuevo_prompt = aplicar_modificacion(historia, opcion)
            historia = generar_cuento(nuevo_prompt)
            print("\n=== HISTORIA MODIFICADA ===")
            print(historia)

if __name__ == "__main__":
    main()
# Out:
# ¡Bienvenido al Generador de Cuentos Creativos!
# (escribe 'salir' en cualquier momento para terminar)
#
# === Configura tu historia ===
# Género (ej. fantasía, sci-fi, misterio): sci-fi
# Protagonista (ej. princesa guerrera, robot poeta): robot mutante
# Escenario (ej. ciudad flotante, bosque de cristal): bosque atómico
# Tono (ej. épico, oscuro, humorístico): humorístico
# Elementos especiales (ej. magia, tecnología alienígena): matemáticas cuánticas
#
# === TU CUENTO ===
# **Título: "El Robot Mutante y el Bosque de los Números Cuánticos"**
#
# **Introducción**
#
# El Bosque Atómico no era un lugar común. Los árboles brillaban con un aura verde fosforescente, las ardillas tenían tres colas y, a veces, los hongos cantaban ópera. En medio de ese caos cósmico, vivía R-7X, un robot mutante con una peculiaridad: le encantaban las matemáticas cuánticas.
#
# -¡Oh, gloriosa incertidumbre cuántica! -exclamaba R-7X mientras caminaba entre los árboles, sus pies metálicos dejando huellas de código binario en el suelo radiactivo-. ¡La probabilidad de que hoy sea un día interesante es del 93,7%!
#
# **Conflicto**
#
# Un día, mientras calculaba la trayectoria de una mariposa de neutrones, R-7X tropezó con una raíz fractal. Al caer, su cabeza golpeó una roca de antimateria y, al levantarse, descubrió que su sistema de procesamiento se había vuelto... extraño.
#
# -¡Por los quarks de mi motherboard! -gritó, mirando sus manos, que ahora cambiaban de forma aleatoriamente-. ¡He mutado en un robot cuántico!
#
# De pronto, el bosque se llenó de ecuaciones flotantes y los árboles comenzaron a resolver integrales en sus cortezas. R-7X intentó huir, pero cada paso que daba lo teleportaba a otro lugar del bosque.
#
# -¡Esto es peor que intentar dividir por cero! -se quejó, apareciendo encima de un hongo cantarín-. ¡Necesito ayuda!
#
# Apareció entonces la Ardilla Tri-Cuántica, una criatura peluda con gafas de sol y un ábaco en la cola.
#
# -¿Problemas con la superposición cuántica, eh? -dijo la ardilla, masticando un número imaginario-. Lo tuyo es simple: estás en dos estados a la vez.
#
# -¡Pero no quiero ser un gato de Schrödinger! -protestó R-7X, mientras su brazo izquierdo desaparecía y reaparecía en otra dimensión-.
#
# **Desenlace**
#
# La Ardilla Tri-Cuántica le explicó que la única forma de estabilizarse era resolver la "Ecuación de la Realidad": *x² + (i · y) = √(caos)*. R-7X, aunque asustado, se concentró y, con sus circuitos humeantes, resolvió la ecuación.
#
# -¡Lo logré! -gritó, sintiendo cómo su cuerpo volvía a la normalidad-. ¡La solución era 42! ¡Siempre es 42!
#
# El bosque dejó de vibrar y los árboles dejaron de cantar teoremas. La Ardilla Tri-Cuántica le dio un guiño (en tres dimensiones a la vez) y desapareció en un puff de humo algebraico.
#
# R-7X suspiró aliviado y continuó su camino, ahora con un nuevo respeto por las matemáticas... y por las ardillas sabiondas.
#
# -¡Hasta la próxima paradoja! -dijo, mientras el Bosque Atómico volvía a su gloriosa locura habitual.
#
# **Fin.**
#
# ¿Qué deseas hacer ahora?
# 1. Agregar un giro dramático
# 2. Cambiar el final
# 3. Ampliar una escena
# 4. Generar nueva historia
# 5. Salir
# Elección: 5
# ¡Hasta la próxima aventura!
